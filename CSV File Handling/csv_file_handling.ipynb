# %%
import pandas as pd

# %%
df1 = pd.read_csv("customers-100.csv",usecols = ["Company","City"])

# %%
df = pd.read_csv("customers-100.csv",skiprows=[0,5])

# %%
df
# Out:
#       1  DD37Cf93aecA6Dc    Sheryl    Baxter                  Rasmussen Group  \
# 0     2  1Ef7b82A4CAAD10   Preston    Lozano                      Vega-Gentry
# 1     3  6F94879bDAfE5a6       Roy     Berry                    Murillo-Perry
# 2     4  5Cef8BFA16c5e3c     Linda     Olsen  Dominguez, Mcmillan and Donovan
# 3     6  2d08FB17EE273F4     Aimee     Downs                     Steele Group
# 4     7  EA4d384DfDbBf77    Darren      Peck     Lester, Woodard and Mitchell
# ..  ...              ...       ...       ...                              ...
# 93   96  cb8E23e48d22Eae      Karl     Greer                        Carey LLC
# 94   97  CeD220bdAaCfaDf      Lynn  Atkinson            Ware, Burns and Oneal
# 95   98  28CDbC0dFe4b1Db      Fred    Guerra                    Schmitt-Jones
# 96   99  c23d1D9EE8DEB0A    Yvonne    Farmer               Fitzgerald-Harrell
# 97  100  2354a0E336A91A1  Clarence    Haynes               Le, Nash and Cross
#
# ...

# %%
df2 = pd.read_csv("customers-100.csv",nrows=40)

# %%
df2
# Out:
#     Index      Customer Id First Name    Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl       Baxter
# 1       2  1Ef7b82A4CAAD10    Preston       Lozano
# 2       3  6F94879bDAfE5a6        Roy        Berry
# 3       4  5Cef8BFA16c5e3c      Linda        Olsen
# 4       5  053d585Ab6b3159     Joanna       Bender
# 5       6  2d08FB17EE273F4      Aimee        Downs
# 6       7  EA4d384DfDbBf77     Darren         Peck
# 7       8  0e04AFde9f225dE      Brett       Mullen
# 8       9  C2dE4dEEc489ae0     Sheryl       Meyers
# 9      10  8C2811a503C7c5a   Michelle    Gallagher
# 10     11  216E205d6eBb815       Carl    Schroeder
# 11     12  CEDec94deE6d69B      Jenna       Dodson
# 12     13  e35426EbDEceaFF     Tracey         Mata
# 13     14  A08A8aF8BE9FaD4   Kristine          Cox
# 14     15  6fEaA1b7cab7B6C      Faith         Lutz
# 15     16  8cad0b4CBceaeec    Miranda      Beasley
# 16     17  a5DC21AE3a21eaA   Caroline        Foley
# ...

# %%
# if found unicode error 
# use code editor and change encoding type
# or find out the ending type if that file and use (encoding="xxx")

# %%
# if found parser error
# use error_bad_lines = True

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              40 non-null     int64
#  1   Customer Id        40 non-null     object
#  2   First Name         40 non-null     object
#  3   Last Name          40 non-null     object
#  4   Company            40 non-null     object
#  5   City               40 non-null     object
#  6   Country            40 non-null     object
#  7   Phone 1            40 non-null     object
#  8   Phone 2            40 non-null     object
#  9   Email              40 non-null     object
#  10  Subscription Date  40 non-null     object
#  11  Website            40 non-null     object
# dtypes: int64(1), object(11)
# memory usage: 3.9+ KB

# %%
# change data type use (dtype={"target":int})

# %%
# make date column as datetime type = (parse_dates=["date"])

# %%
def rename(name):
    if name == "Rasmussen Group":
        return "RG"
    else:
        return name

# %%
df3 = pd.read_csv("customers-100.csv",converters={"Company":rename})

# %%
df3
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                                RG       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df2 = pd.read_csv("customers-100.csv",chunksize=19)

# %%
for chunck in df2:
    print(chunck.shape)
# Out:
# (19, 12)
# (19, 12)
# (19, 12)
# (19, 12)
# (19, 12)
# (5, 12)
